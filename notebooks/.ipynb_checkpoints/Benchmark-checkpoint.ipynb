# %%
import os
import json
import pandas as pd
from pathlib import Path
import numpy as np

# %%
def get_stats(stats_json):
    with open(stats_json) as f:
        stats = json.load(f)
    return stats

# %%
# root_dir = Path('/h/suo/dev/tree-search-planning/muzero-general/out')
root_dir = Path('/h/suo/dev/tree-search-planning/out')

# %%
evaluations = []
for env in os.listdir(root_dir):
    if not (root_dir / env).is_dir():
            continue

    for model in os.listdir(root_dir / env):
        for run in os.listdir(root_dir / env / model):
            try:
                stats_json = next((root_dir / env / model / run).glob('*.stats.json'))
                evaluations.append([env, model, run, stats_json])
            except:
                pass

# %%
evaluations_df = pd.DataFrame(evaluations, columns=['env', 'model', 'run', 'stats_json'])
evaluations_df['stats_dict'] = evaluations_df['stats_json'].apply(get_stats)
evaluations_df
# Out:
#               env                      model  \
# 0      highway-v0                     MuZero
# 1      HighwayEnv               MDPGapEAgent
# 2      HighwayEnv               MDPGapEAgent
# 3      HighwayEnv               MDPGapEAgent
# 4      HighwayEnv  DeterministicPlannerAgent
# 5      HighwayEnv  DeterministicPlannerAgent
# 6      HighwayEnv  DeterministicPlannerAgent
# 7      HighwayEnv                  MCTSAgent
# 8      HighwayEnv                  MCTSAgent
# 9      HighwayEnv                  MCTSAgent
# 10     HighwayEnv                  MCTSAgent
# 11     HighwayEnv                   DQNAgent
# 12     HighwayEnv                   DQNAgent
# 13     HighwayEnv                   DQNAgent
# 14     HighwayEnv                   FTQAgent
# 15     HighwayEnv                   FTQAgent
# 16     HighwayEnv                   FTQAgent
# 17     HighwayEnv                   FTQAgent
# 18  RoundaboutEnv                   DQNAgent
# 19  RoundaboutEnv                   DQNAgent
# 20  RoundaboutEnv                  MCTSAgent
# 21  RoundaboutEnv                  MCTSAgent
# 22  RoundaboutEnv  DeterministicPlannerAgent
# 23  RoundaboutEnv  DeterministicPlannerAgent
# 24  CrossMergeEnv  DeterministicPlannerAgent
#
#                                    run  \
# 0            run_20210408-065305_25133
# 1       baseline_20210410-084339_51988
# 2       baseline_20210414-082247_38849
# 3       baseline_20210410-084630_25529
# 4            opd_20210410-084339_51989
# 5            opd_20210414-082246_38851
# 6            opd_20210410-084629_25530
# 7       budget_25_20210414-084512_3774
# 8      budget_25_20210414-082246_38854
# 9    iterations10_20210410-080832_7057
# 10  iterations10_20210410-084629_25531
# 11            dqn_20210410-080837_7058
# 12            dqn_20210409-035853_4516
# 13           dqn_20210410-082841_47165
# 14      baseline_20210410-075811_29230
# 15       baseline_20210410-081602_3661
# 16       baseline_20210410-080307_2290
# 17      baseline_20210410-082257_68957
# 18           dqn_20210414-083630_35018
# 19           dqn_20210414-082540_70447
# 20     budget_25_20210414-141912_81500
# 21  iterations10_20210414-082326_30632
# 22           opd_20210414-202247_15783
# 23            opd_20210414-195959_8111
# 24           opd_20210414-204236_21559
#
#                                            stats_json  \
# 0   /h/suo/dev/tree-search-planning/out/highway-v0...
# 1   /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 2   /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 3   /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 4   /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 5   /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 6   /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 7   /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 8   /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 9   /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 10  /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 11  /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 12  /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 13  /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 14  /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 15  /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 16  /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 17  /h/suo/dev/tree-search-planning/out/HighwayEnv...
# 18  /h/suo/dev/tree-search-planning/out/Roundabout...
# 19  /h/suo/dev/tree-search-planning/out/Roundabout...
# 20  /h/suo/dev/tree-search-planning/out/Roundabout...
# 21  /h/suo/dev/tree-search-planning/out/Roundabout...
# 22  /h/suo/dev/tree-search-planning/out/Roundabout...
# 23  /h/suo/dev/tree-search-planning/out/Roundabout...
# 24  /h/suo/dev/tree-search-planning/out/CrossMerge...
#
#                                            stats_dict
# 0   {'initial_reset_timestamp': 1617879186.096059,...
# 1   {'initial_reset_timestamp': 1618058619.609562,...
# 2   {'initial_reset_timestamp': 1618402967.0445936...
# 3   {'initial_reset_timestamp': 1618058790.161311,...
# 4   {'initial_reset_timestamp': 1618058619.6110404...
# 5   {'initial_reset_timestamp': 1618402966.9857082...
# 6   {'initial_reset_timestamp': 1618058790.08241, ...
# 7   {'initial_reset_timestamp': 1618404312.0606859...
# 8   {'initial_reset_timestamp': 1618402966.984263,...
# 9   {'initial_reset_timestamp': 1618056512.0742393...
# 10  {'initial_reset_timestamp': 1618058790.106909,...
# 11  {'initial_reset_timestamp': 1618056517.8748121...
# 12  {'initial_reset_timestamp': 1617955134.2936697...
# 13  {'initial_reset_timestamp': 1618057722.3066812...
# 14  {'initial_reset_timestamp': None, 'timestamps'...
# 15  {'initial_reset_timestamp': None, 'timestamps'...
# 16  {'initial_reset_timestamp': None, 'timestamps'...
# 17  {'initial_reset_timestamp': None, 'timestamps'...
# 18  {'initial_reset_timestamp': 1618403790.7120154...
# 19  {'initial_reset_timestamp': 1618403140.6880665...
# 20  {'initial_reset_timestamp': 1618424352.3365767...
# 21  {'initial_reset_timestamp': 1618403006.7674654...
# 22  {'initial_reset_timestamp': 1618446167.5847013...
# 23  {'initial_reset_timestamp': 1618444799.5045815...
# 24  {'initial_reset_timestamp': 1618447356.9380393...

# %%
evaluations_df = evaluations_df[evaluations_df['env'] == 'CrossMergeEnv']

# %%
# def mean_episode_length(stat_dict):
#     return np.mean(stat_dict['episode_lengths'])
def mean_total_reward(stat_dict):
    return np.mean(stat_dict['episode_rewards'])
def std_total_reward(stat_dict):
    return np.std(stat_dict['episode_rewards'])
def p_crashed(stat_dict):
    ep_crashed = [int(any(ep)) for ep in stat_dict['episode_crashed']]
    return np.mean(ep_crashed)
def mean_speed(stat_dict):
    ep_speed = [np.mean(ep) for ep in stat_dict['episode_speed']]
    return np.mean(ep_speed)
def std_speed(stat_dict):
    ep_speed = [np.mean(ep) for ep in stat_dict['episode_speed']]
    return np.std(ep_speed)

# %%
# evaluations_df['mean_episode_length'] = evaluations_df['stats_dict'].apply(mean_episode_length)
evaluations_df['mean_episode_reward'] = evaluations_df['stats_dict'].apply(mean_total_reward)
evaluations_df['std_episode_reward'] = evaluations_df['stats_dict'].apply(std_total_reward)
evaluations_df['p_crashed'] = evaluations_df['stats_dict'].apply(p_crashed)
evaluations_df['mean_speed'] = evaluations_df['stats_dict'].apply(mean_speed)
evaluations_df['std_speed'] = evaluations_df['stats_dict'].apply(std_speed)
# Out:
# /h/suo/software/miniconda3/envs/treesearch/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /h/suo/software/miniconda3/envs/treesearch/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /h/suo/software/miniconda3/envs/treesearch/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /h/suo/software/miniconda3/envs/treesearch/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /h/suo/software/miniconda3/envs/treesearch/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
evaluations_df
# Out:
#               env                      model                        run  \
# 24  CrossMergeEnv  DeterministicPlannerAgent  opd_20210414-204236_21559
#
#                                            stats_json  \
# 24  /h/suo/dev/tree-search-planning/out/CrossMerge...
#
#                                            stats_dict  mean_episode_reward  \
# 24  {'initial_reset_timestamp': 1618447356.9380393...                 1.06
#
#     std_episode_reward  p_crashed  mean_speed  std_speed
# 24            1.690089       0.14   20.767369   5.229379

# %%
evaluations_df.set_index(['env', 'model'])[['mean_episode_reward', 'std_episode_reward', 'p_crashed', 'mean_speed', 'std_speed']]
# Out:
#                                          mean_episode_reward  \
# env           model
# CrossMergeEnv DeterministicPlannerAgent                 1.06
#
#                                          std_episode_reward  p_crashed  \
# env           model
# CrossMergeEnv DeterministicPlannerAgent            1.690089       0.14
#
#                                          mean_speed  std_speed
# env           model
# CrossMergeEnv DeterministicPlannerAgent   20.767369   5.229379
